# %%
from aux_fns import *
data_path = 'data_to_train'

# %%
data_config = DataConfig(data_path)

# %%
bd = BenetechDataset(data_config, task='classify', stage='train')

# %%
bd.__getitem__(0)[0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=466x281>

# %%
bd.__getitem__(0)[1]['source']
bd.__getitem__(0)[1]['chart-type']
bd.__getitem__(0)[1]['plot-bb']
bd.__getitem__(0)[1]['text']
bd.__getitem__(0)[1]['axes']
bd.__getitem__(0)[1]['data-series']
# Out:
# [{'x': 'Malawi', 'y': 837799.95244483},
#  {'x': 'Malaysia', 'y': 960480.6137135166},
#  {'x': 'Maldives', 'y': 750170.9086814824},
#  {'x': 'Mali', 'y': 697593.4824234738},
#  {'x': 'Malta', 'y': 574912.8211547872},
#  {'x': 'Martinique', 'y': 452232.1598861007},
#  {'x': 'Mauritania', 'y': 653778.9605418},
#  {'x': 'Mauritius', 'y': 539861.2036494482},
#  {'x': 'Mayotte', 'y': 417180.54238076165},
#  {'x': 'Melanesia', 'y': 574912.8211547872}]

# %%
bd.__getitem__(0)[1].keys()
# Out:
# dict_keys(['source', 'chart-type', 'plot-bb', 'text', 'axes', 'data-series'])

# %%
Image.open(data_config.train_img_folder/'cc68f19b708c.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=515x276>
